# %%
import pytest
from pprint import pprint
import sys
import os

# %%
x = os.path.abspath(os.path.join(os.getcwd(),'../../'))

if x not in sys.path:
    sys.path.append(x)
    print(x + ' added to path')
# Out:
# /Users/joeyd/Documents/JoeyDCareer/GitHub/MasteringSpacy/Spacy_Tutorials/ner_food_ingredients/notebooks added to path

# %%
from rank_pair_tree import RankPair, RankPairTreeNode, RankPairTree, RankPairTreeRank

# %%
urls = [
    'https://groceries.asda.com', 
    'https://groceries.asda.com/promotion',
    'https://groceries.asda.com/product', 
    'https://groceries.asda.com/promotion/2-for-7/ls91300',
    'https://groceries.asda.com/product/1000338629556', 
    'https://groceries.asda.com/super_dept/veganuary/1215686171560', 
    'https://groceries.asda.com/cat/fresh-food-bakery/103099', 
    'https://groceries.asda.com/product/1000334423970',
]
rankTree = RankPairTree(urls[0])
for url in urls[1:]:
    rankTree.embedUrl(url)

# %%
rankTree.drawGraph()

# %%
from api import Neo4jApi

# %%
neo4jApi = Neo4jApi()

# %%
neo4jApi.add_tree_to_graph(rankTree.treeState)
# Out:
# Query failed: {code: Neo.ClientError.Security.Unauthorized} {message: The client is unauthorized due to authentication failure.}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/bg/jt6894r57cb6l1ln5j32l8k80000gn/T/ipykernel_91007/3423554033.py in <module>
# ----> 1 neo4jApi.add_tree_to_graph(rankTree.treeState)
#
# ~/Documents/JoeyDCareer/GitHub/MasteringSpacy/Spacy_Tutorials/ner_food_ingredients/notebooks/repository/graph/api.py in add_tree_to_graph(self, node, batch_size)
#      93             res = self._conn.query(query,
#      94                             parameters = params(batch))
# ---> 95             print(res)
#      96             total += res[0]['total']
#      97             batch += 1
#
# TypeError: 'NoneType' object is not subscriptable
